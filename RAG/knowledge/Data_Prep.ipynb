# %% [markdown]
# ## Data Preparation For RAG (Unstructured and Structured Data)

# %% [markdown]
# ### Importing Libraries and Utilities

# %%
# %pip install langchain openai

# %% [markdown]
# ### Loading Data into the Databricks File System
